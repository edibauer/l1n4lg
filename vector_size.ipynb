# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
v = np.array([6, 3])
print(v)
# Out:
# [6 3]

# %%
v_mag = np.sqrt(v[0]**2 + v[1]**2)
print(v_mag)
# Out:
# 6.708203932499369

# %%
v_mag2 = np.linalg.norm(v)
print(v_mag2)
# Out:
# 6.708203932499369
